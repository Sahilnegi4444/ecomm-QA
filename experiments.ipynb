# %%
import pandas as pd
import numpy as np
from sqlalchemy import text, create_engine
import warnings
warnings.filterwarnings("ignore")

# %%
DATABASE_URL = 'mysql+pymysql://root:Lihasigen%404444@localhost:3306/amazon_data_db'
engine = create_engine(DATABASE_URL)

# %%
# for testing data
query = "SELECT * FROM amazon_dataframe LIMIT 10000"  
df = pd.read_sql(query, engine)

# %%
df['category'].value_counts()
# Out:
# category
# All Beauty                  7747
# Health & Personal Care       851
# Premium Beauty               753
# Amazon Home                  173
# Tools & Home Improvement     145
# AMAZON FASHION                56
# Industrial & Scientific       50
# Grocery                       24
# Toys & Games                  16
# Pet Supplies                   9
# Sports & Outdoors              8
# Appliances                     7
# Baby                           6
# All Electronics                4
# Office Products                4
# Arts, Crafts & Sewing          2
# Computers                      1
# Name: count, dtype: int64

# %%
df[['review_title', 'category', 'review_headline', 'rating', 'price']].head(3)
# Out:
#                                         review_title    category  \
# 0  Terra Tattoos Tropical Hawaiian Metallic Tatto...  All Beauty
# 1  Palmer's Coconut Oil Formula Moisture Boost Co...  All Beauty
# 2  Chloven 55 Pcs Premium Velvet Hair Scrunchies ...  All Beauty
#
#                                    review_headline  rating  price
# 0          Gasoline!! Seriously reeks of gasoline!     1.0   9.87
# 1  This stuff is a luxurious vacation in a bottle.     5.0  19.85
# 2                                               A+     5.0  11.99

# %%
df.head(3)
# Out:
#    rating                                  review_headline  \
# 0     1.0          Gasoline!! Seriously reeks of gasoline!
# 1     5.0  This stuff is a luxurious vacation in a bottle.
# 2     5.0                                               A+
#
#                                              reviews parent_asin    category  \
# 0  Opened the package & instant migraine. I canno...  B00Z03RC80  All Beauty
# 1  It smells heavenly but not overwhelming at all...  B0BHP2ZS4G  All Beauty
# 2                                          Excellent  B081RW1PLY  All Beauty
#
#                                        product_title  average_rating  \
# 0  Terra Tattoos Tropical Hawaiian Metallic Tatto...             4.3
# 1  Palmer's Coconut Oil Formula Moisture Boost Co...             4.6
# 2  Chloven 55 Pcs Premium Velvet Hair Scrunchies ...             4.7
#
#    rating_number                                           features  \
# 0            882  OVER 75+ New tropical mermaid temporary metall...
# 1           1507  Hydrating Shampoo: This rich, creamy, non stri...
# 2          11451  ?55 PIECES of HIGH QUALITY SCRUNCHIES?, Our ve...
#
#                                          description  price          store  \
# 0                                                      9.87  Terra Tattoos
# 1  Palmer\u2019s Coconut Oil Formula Moisture Boo...  19.85       Palmer's
# 2                                                     11.99        Chloven
#
#                                           categories  \
# 0  Beauty & Personal Care, Makeup, Body, Temporar...
# 1  Beauty & Personal Care, Hair Care, Shampoo & C...
# 2  Beauty & Personal Care, Hair Care, Hair Access...
#
#                                              details
# 0  Color: Gold,Silver, Brand: Terra Tattoos, Size...
# 1  Is Discontinued By Manufacturer: No, Product D...
# 2  Brand: Chloven, Hair Type: Long, Material: Vel...

# %%
df.columns
# Out:
# Index(['rating', 'review_headline', 'reviews', 'parent_asin', 'category',
#        'product_title', 'average_rating', 'rating_number', 'features',
#        'description', 'price', 'store', 'categories', 'details'],
#       dtype='object')

# %%
# group by parent_asin

products = df.groupby('parent_asin').agg({
    'product_title': 'first',          # Take first product title
    'category': 'first',                # Take first category
    'price': df['category']'mean',                    # Average price
    'rating': 'mean',                   # Average rating
    'rating_number': 'first',           # Number of reviews
    'reviews': lambda x: ' '.join(x.astype(str)[:10]),  # Combine first 10 reviews
    'features': 'first',                # Product features
    'description': 'first',             # Product description
    'details': 'first'                  # Product details
}).reset_index()

# %%
sample = products.iloc[0]
print(f"Product: {sample['product_title']}")
print(f"Category: {sample['category']}")
print(f"Avg Rating: {sample['rating']:.1f}")
print(f"Price: ${sample['price']:.2f}")
# Out:
# Product: Bond No 9 Chez Bond Cologne for Men 1.7 oz Eau De Parfum Spray
# Category: All Beauty
# Avg Rating: 3.0
# Price: $217.17

# %%
df.columns
# Out:
# Index(['rating', 'review_headline', 'reviews', 'parent_asin', 'category',
#        'product_title', 'average_rating', 'rating_number', 'features',
#        'description', 'price', 'store', 'categories', 'details'],
#       dtype='object')

# %%
# create text embeddings

def create_embeddings(row):
    
    parts = []
    parts.append(row['product_title'])

    if pd.notna(row['category']):
        parts.append(f"Category:{row['category']}")

    if pd.notna(row['features']):
        parts.append(f"Features:{str(row['features'])[:300]}")
        
    if pd.notna(row['description']):
        parts.append(f"Description:{str(row['description'])[:300]}")

    if pd.notna(row['reviews']):
        parts.append(f"Customer Reviews:{str(row['reviews'])[:600]}")

    if pd.notna(row['price']):
        parts.append(f"Price:${row['price']:.2f}")
    
    parts.append(f"Rating:{row['rating']}/5")

    return " | ".join(parts)

# %%
products['combined_text'] = products.apply(create_embeddings, axis=1)
print("Combined text:")
print(products['combined_text'].iloc[3][:800] + "...\n")
# Out:
# Combined text:
# Face Moisturizer by Olay, Complete All Day Moisturizer With Sunscreen Broad Spectrum SPF 15 - Sensitive, 4 fl. Oz, 1 unit | Category:All Beauty | Features:Gentle formula provides 8 hours of long-lasting hydration for sensitive skin, Fragrance-free moisturizer helps prevent skin damage by protecting against the suns harmful rays with SolaSheer Sensitive Technology, 100% fragrance-free, and PABA-free formula. Non-greasy, Conditions skin\u2019s surface w | Description:Protect against the #1 cause of aging skin - damage from the sun. Recommended by the Skin Cancer Foundation, Olay Complete Daily Moisturizer with Broad Spectrum Sunscreen SPF 15 Facial Moisturizer, with UVA/UVB protection, provides 8 hours of hydration for sensitive skin. This gentle, lightweight lo | Customer Reviews:I've had i...

# %%
products.head()
# Out:
#   parent_asin                                      product_title    category  \
# 0  9790770952  Bond No 9 Chez Bond Cologne for Men 1.7 oz Eau...  All Beauty
# 1  9839215027             Nu Skin Enhancer Skin Conditioning Gel  All Beauty
# 2  B000052YN9  Eucerin Original Healing Cream, Fragrance Free...  All Beauty
# 3  B000052YQ2  Face Moisturizer by Olay, Complete All Day Moi...  All Beauty
# 4  B000052YQN                  Pond's Cold Cream Cleanser 3.5 oz  All Beauty
#
#     price  rating  rating_number  \
# 0  217.17     3.0             32
# 1   20.00     4.0            651
# 2   29.06     5.0           6593
# 3    9.49     5.0           3135
# 4    7.29     2.0           7691
#
#                                              reviews  \
# 0  The product itself smells good. However, the b...
# 1                                          I like it
# 2  This is wonderful for dry skin and is very hea...
# 3  I've had issues with some moisturizers lately ...
# 4  No security seal on jar, had to send it back! ...
#
#                                             features  \
# 0
# 1  Nuskin Nu Skin Enhancer Skin Conditioning Gel,...
# 2  Helps to Heal and Protect: This Eucerin Healin...
# 3  Gentle formula provides 8 hours of long-lastin...
# 4  3.5oz jar of Ponds Cold Cream Cleanser, Dissol...
#
#                                          description  \
# 0  Product Description, Bond No 9 Chez Bond Colog...
# 1  With conditioning panthenol and soothing aloe ...
# 2  Eucerin Original Healing Cream is a time-teste...
# 3  Protect against the #1 cause of aging skin - d...
# 4  Dissolves all traces of makeup and moisturizes...
#
#                                              details  \
# 0  Brand: Bond No. 9, Item Form: Spray, Item Volu...
# 1  Brand: Nu Skin, Scent: Aloe Vera, Item Form: G...
# 2  Brand: Eucerin, Scent: Fragrance Free, Item Fo...
# 3  Brand: Olay, Scent: Unscented, Item Form: Loti...
# 4  Item Form: Cream, Skin Type: Dry, Brand: Ponds...
#
#                                        combined_text
# 0  Bond No 9 Chez Bond Cologne for Men 1.7 oz Eau...
# 1  Nu Skin Enhancer Skin Conditioning Gel | Categ...
# 2  Eucerin Original Healing Cream, Fragrance Free...
# 3  Face Moisturizer by Olay, Complete All Day Moi...
# 4  Pond's Cold Cream Cleanser 3.5 oz | Category:A...

# %%
# Generate embeddings

from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2')

print("Model loaded")
# Out:
# Model loaded

# %%
embeddings = model.encode(
    products['combined_text'].tolist(),
    show_progress_bar=True,
    batch_size=32
)

print(f"Embedding shape: {embeddings.shape}")
# Out:
# Batches: 100%|██████████| 256/256 [01:25<00:00,  2.99it/s]
# Embedding shape: (8187, 384)

# %%
# client.delete_collection(name="products")

# %%
metadata_df
# Out:
#                                           product_title  \
# 0     Bond No 9 Chez Bond Cologne for Men 1.7 oz Eau...
# 1                Nu Skin Enhancer Skin Conditioning Gel
# 2     Eucerin Original Healing Cream, Fragrance Free...
# 3     Face Moisturizer by Olay, Complete All Day Moi...
# 4                     Pond's Cold Cream Cleanser 3.5 oz
# ...                                                 ...
# 8182  DRMTLGY Tinted Moisturizer with SPF 46. Univer...
# 8183  TROIAREUKE A.G.T HYDRO ESSENCE l Deep Hydratin...
# 8184  Upgraded 10x Magnifying Lighted Makeup Mirror ...
# 8185  Dove Sensitive Skin Micellar Water Body Wash, ...
# 8186  Electric Callus Remover for Feet, 17 in 1 Rech...
#
#                     category   price  rating
# 0                 All Beauty  217.17     3.0
# 1                 All Beauty   20.00     4.0
# 2                 All Beauty   29.06     5.0
# 3                 All Beauty    9.49     5.0
# 4                 All Beauty    7.29     2.0
# ...                      ...     ...     ...
# 8182              All Beauty   27.95     5.0
# 8183              All Beauty   52.00     4.0
# 8184             Amazon Home   19.99     5.0
# 8185                     0.0   22.94     5.0
# 8186  Health & Personal Care   19.99     5.0
#
# [8187 rows x 4 columns]

# %%
# Set-up Vector search

import chromadb
client = chromadb.Client()

collection = client.create_collection(name="products")

metadata_df = products[['product_title', 'category', 'price', 'rating']].copy()

metadata_df = metadata_df.where(pd.notna(metadata_df), (0.0))           #replace the null value with 0

metadatas = metadata_df.to_dict('records')

collection.add(
    embeddings=embeddings.tolist(),
    documents=products['combined_text'].tolist(),
    ids=products['parent_asin'].tolist(),
    metadatas=metadatas
)
# Out:
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event CollectionAddEvent: capture() takes 1 positional argument but 3 were given

# %%
test_query = "facewash for oily skin"

# Encode the query
query_embedding = model.encode([test_query])

# Search
results = collection.query(
    query_embeddings=query_embedding.tolist(),
    n_results=5
)

print(f"\n✅ Found {len(results['ids'][0])} results:")
# Out:
# Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given
# ✅ Found 5 results:

# %%
for i, (id, metadata, distance) in enumerate(zip(
    results['ids'][0], 
    results['metadatas'][0], 
    results['distances'][0]
)):
    print(f"\n{i+1}. {metadata['product_title']}")
    print(f"   Category: {metadata['category']}")
    print(f"   Rating: {metadata['rating']:.1f}/5.0")
    print(f"   Price: ${metadata['price']:.2f}")
    print(f"   Similarity: {1 - distance:.3f}")
# Out:
# 1. Garnier SkinActive Face Wash with Green Tea, Oily Skin, 6.7 Fluid Ounce (Pack of 2)
#    Category: All Beauty
#    Rating: 4.0/5.0
#    Price: $32.99
#    Similarity: 0.411
#
# 2. Golden Grooming Co. Men Face Wash - -Nature-Based & Organic Mens Face Wash - Rich Foaming Daily Face Cleanser For Men - Ideal for Sensitive, Oily, Normal & Combo Skin - Black Men Skin Care
#    Category: All Beauty
#    Rating: 3.0/5.0
#    Price: $12.99
#    Similarity: 0.365
#
# 3. facetheory Clarifying Cleanser C2 - Oil Free Salicylic Acid Face Wash, Exfoliating Face Scrub and Chemical Peel, Deeply Cleanse Pores, Vegan and Cruelty-Free, Made in the UK | 5.7 fl oz
#    Category: All Beauty
#    Rating: 5.0/5.0
#    Price: $16.00
#    Similarity: 0.334
#
# 4. Basis Cleaner Clean Face Wash, 6 Ounce (Pack of 3)
#    Category: All Beauty
#    Rating: 2.0/5.0
#    Price: $9.87
#    Similarity: 0.329
#
# 5. Acne Control Face Wash For Oily Acne Skin Prone to Breakouts, 8oz
#    Category: All Beauty
#    Rating: 4.0/5.0
#    Price: $29.99
#    Similarity: 0.301

# %%
# Create a Search function 

def search_products(query, k=5):
    """
    Args: 
    query: User search
    k: No of similar search results
    
    Returns:
    List of matching products with metadata
    """
    
    query_embedding = model.encode([query])

    results = collection.query(
        query_embeddings= query_embedding.tolist(),
        n_results=k
    )

    return results

# %%
search_products("shampoo for hairfall", k=3)
# Out:
# {'ids': [['B0C4LYR6Z3', 'B001A6L7UA', 'B00FXH7YZ4']],
#  'distances': [[0.7068009376525879, 0.7318345904350281, 0.7630177140235901]],
#  'metadatas': [[{'category': 'All Beauty',
#     'price': 15.3,
#     'product_title': 'WOW Skin Science Apple Cider Vinegar Shampoo & Conditioner Set with Coconut & Avocado Oil - Men and Women Gentle Shampoo Set - Hair Growth Shampoo for Thinning Hair & Loss - Sulfate & Paraben Free',
#     'rating': 5.0},
#    {'category': 'All Beauty',
#     'price': 33.99,
#     'product_title': 'Hair Loss Therapy Conditioner | Best conditioner to promote and encourage healthy looking hair | Nutritive ingredients the feed and hydrate your hair',
#     'rating': 2.0},
#    {'category': 'All Beauty',
#     'price': 22.97,
#     'product_title': 'Hair Shampoo for Damaged Hair - Fragrance Free Moisturizing Shampoo with Organic Aloe, Coconut Oil & Rosemary - Mens & Womens Shampoo - Clarifying Shampoo Best for Curly, Fine, Thick, Dry or Oily Hair',
#     'rating': 5.0}]],
#  'embeddings': None,
#  'documents': [['WOW Skin Science Apple Cider Vinegar Shampoo & Conditioner Set with Coconut & Avocado Oil - Men and Women Gentle Shampoo Set - Hair Growth Shampoo for Thinning Hair & Loss - Sulfate & Paraben Free | Category:All Beauty | Features:Nourishing Detox Treatment - Our hair shampoo and conditioner acv hair rinse open clogged hair follicles and breaks down itchy build-up. Hydrating Shampoo and Conditioner with a nourishing oil blend is key to restore elasticity and healthy shine to your hair, Fight Flakes and Defeat Dandruff - A sha | Description: | Customer Reviews:I have tried many shampoos, trying to stop my hair from falling out so much and getting damaged.  This has been one of the first products that truly does what it says! I usually don\'t fall for ads I see on Facebook but when I saw I could buy it here on Amazon I thought I\'d give it a try.<br />First thing I noticed after using WOW was my tangles would "work" out instead of my hair just breaking off.<br />Second thing was that there was less hair caught in my brush or left on the counter!!<br />As I have continued to use it I could actually feel my hair becoming more healthy and stronger. Then I | Price:$15.30 | Rating:5.0/5',
#    'Hair Loss Therapy Conditioner | Best conditioner to promote and encourage healthy looking hair | Nutritive ingredients the feed and hydrate your hair | Category:All Beauty | Features:IMPROVED HAIR APPEARANCE: No more bad hair days due to thinning or sparse hair areas. Your hair will look more vibrant and voluminous after just one use. Your hair and scalp will thank you., PROTECTS AND STRENGTHENS YOUR HAIR: Crafted with goodies like Hydrolyzed Jojoba Protein that help add a prote | Description: | Customer Reviews:Same as with shampoo, I used it for 3 to 4 months and still kept losing a lot of hair.  Paid to much for it not to  help. | Price:$33.99 | Rating:2.0/5',
#    'Hair Shampoo for Damaged Hair - Fragrance Free Moisturizing Shampoo with Organic Aloe, Coconut Oil & Rosemary - Mens & Womens Shampoo - Clarifying Shampoo Best for Curly, Fine, Thick, Dry or Oily Hair | Category:All Beauty | Features:At Christina Moss Naturals we only use clean pure ingredients that make the best shampoo for all hair types. Our Shampoo is unscented and works great as a moisturizing shampoo, a womens shampoo, a mens shampoo and is even gentle enough for kids too., For hydration we use Aloe Vera, Shea Butter, Oliv | Description: | Customer Reviews:I have been using this shampoo for about a week now and love it. It only takes a generous quarter-sized amount to really lather up my thick, shoulder length hair, and leaves it squeaky clean. I also purchased the conditioner which I also love and left a separate review for. | Price:$22.97 | Rating:5.0/5']],
#  'uris': None,
#  'data': None,
#  'included': ['metadatas', 'documents', 'distances']}

# %%
#Connect to LLM(Ollama)

import requests

def generate_response(prompt):
    response = requests.post(
        'http://localhost:11434/api/generate',
        json={
            'model':'llama3.1:8b',
            'prompt': prompt,
            'stream':False,
        }
    )
    return response.json()['response']

# %%
print(generate_response("Nature-Based & Organic Mens Face Wash"))
# Out:
# Here are some great options for Nature-Based and Organic Men's Face Wash:
#
# 1. **Burt's Bees Sensitive Skin Facial Cleanser**: Made with aloe vera, chamomile, and green tea extract to soothe and calm sensitive skin.
# 2. **Acure Organics Mint To Be Facial Cleanser**: Contains burdock root, argan stem cells, and argan oil to cleanse and balance the skin.
# 3. **Andalou Naturals Fruit Stem Cell Revitalizing Mist & Face Wash**: Enriched with resveratrol, vitamin C, and fruit stem cells to revitalize and protect the skin.
# 4. **Desert Essence Thoroughly Clean Facial Cleanser**: Made with aloe vera, tea tree oil, and burdock root to gently clean and balance the skin.
# 5. **Dr. Bronner's Castile Soap**: A natural, biodegradable soap made from organic oils like coconut, olive, and jojoba.
# 6. **The Body Shop Tea Tree Oil Facial Cleanser**: Contains a blend of tea tree oil, witch hazel, and aloe vera to cleanse and reduce acne.
# 7. **Jason Natural Purifying Neem Face Wash**: Made with neem extract, tea tree oil, and aloe vera to deeply clean and purify the skin.
# 8. **Lavera Men's Facial Cleanser**: Contains natural ingredients like chamomile, lavender, and green tea extract to soothe and calm the skin.
# 9. **Mountain Rose Herbs Organic Face Wash**: Made with certified organic ingredients like rosehip oil, aloe vera, and green tea extract.
# 10. **Now Foods Men's Daily Facial Cleaner**: Contains a blend of natural ingredients like vitamin E, green tea extract, and aloe vera to cleanse and protect the skin.
#
# When choosing a Nature-Based or Organic face wash for men, look for the following:
#
# * **Certifications**: Look for certifications from reputable organizations like USDA Organic, Natural Products Association (NPA), or Leaping Bunny.
# * **Natural ingredients**: Opt for products with natural ingredients like essential oils, herbs, and plant extracts.
# * **Minimal harsh chemicals**: Avoid products containing harsh chemicals like sulfates, parabens, and phthalates.
# * **pH balanced**: Choose a product that is pH balanced to avoid disrupting the skin's natural pH.
#
# Remember, always read the ingredient label and follow the instructions carefully before using any new skincare product.

# %%
def chatbot(user_query, k=5):
    """
    Complete RAG chatbot
    """
    
    # 1. Search for relevant products
    print("\n🔍 Searching for relevant products...")
    results = search_products(user_query, k=k)
    
    # 2. Format context
    context = "Here are the relevant products:\n\n"
    for i, meta in enumerate(results['metadatas'][0]):
        context += f"{i+1}. {meta['product_title']}\n"
        context += f"   Category: {meta['category']}\n"
        context += f"   Rating: {meta['rating']:.1f}/5.0\n"
        context += f"   Price: ${meta['price']:.2f}\n\n"
    
    # 3. Create prompt
    prompt = f"""You are a helpful e-commerce assistant. 

User asked: "{user_query}"

{context}

Provide a helpful recommendation explaining which product(s) best match their needs and why. Be frindly, kind and specific."""

    # 4. Generate response
    print("🤖 Generating response...")
    response = generate_response(prompt)
    
    print(f"\n💬 Chatbot: {response}")
    
    
    return response

# Test it!
chatbot("HOw do you recommend WOW Skin Science Apple Cider Vinegar Shampoo & Conditioner?")
# Out:
# 🔍 Searching for relevant products...
# 🤖 Generating response...
#
# 💬 Chatbot: I'm so happy to help you find the perfect Apple Cider Vinegar Shampoo & Conditioner set that suits your hair type and needs!
#
# Based on our product selection, I highly recommend **Option 1: WOW Skin Science Apple Cider Vinegar Shampoo & Conditioner Set** ($15.30). Here's why:
#
# * **Excellent rating**: This product has a perfect 5.0/5.0 rating from customers who have used it, which means they're extremely satisfied with the results.
# * **Multi-benefit formula**: The set contains coconut and avocado oil, making it suitable for men and women with dry or damaged hair, as well as those looking to promote hair growth and reduce thinning.
# * **Sulfate-free and paraben-free**: This product is gentle on your scalp and locks in moisture without stripping your hair of its natural oils.
# * **Affordable price**: At $15.30, this set offers excellent value for the quality and benefits it provides.
#
# While the other options are also great products, I wouldn't recommend them as much as WOW Skin Science due to the following reasons:
#
# * **Nature Love** is a bit pricier ($24.85) and has a similar formula, but not significantly better.
# * **Hawaiian Silky** has a 4-star rating (compared to 5 stars for WOW Skin Science), which means some customers may not be as satisfied with the results.
# * **MOUNTAIN TOP** has a lower rating (3.0/5.0) and is relatively inexpensive ($8.33), but it seems like there are better options available for similar prices.
# * **Aveeno** has a very low rating (1.0/5.0) and may not be the best choice, considering its poor customer reviews.
#
# If you have any specific hair concerns or preferences, I'd be happy to help you narrow down your options further!
# "I'm so happy to help you find the perfect Apple Cider Vinegar Shampoo & Conditioner set that suits your hair type and needs!\n\nBased on our product selection, I highly recommend **Option 1: WOW Skin Science Apple Cider Vinegar Shampoo & Conditioner Set** ($15.30). Here's why:\n\n* **Excellent rating**: This product has a perfect 5.0/5.0 rating from customers who have used it, which means they're extremely satisfied with the results.\n* **Multi-benefit formula**: The set contains coconut and avocado oil, making it suitable for men and women with dry or damaged hair, as well as those looking to promote hair growth and reduce thinning.\n* **Sulfate-free and paraben-free**: This product is gentle on your scalp and locks in moisture without stripping your hair of its natural oils.\n* **Affordable price**: At $15.30, this set offers excellent value for the quality and benefits it provides.\n\nWhile the other options are also great products, I wouldn't recommend them as much as WOW Skin Science due to the following reasons:\n\n* **Nature Love** is a bit pricier ($24.85) and has a similar formula, but not significantly better.\n* **Hawaiian Silky** has a 4-star rating (compared to 5 stars for WOW Skin Science), which means some customers may not be as satisfied with the results.\n* **MOUNTAIN TOP** has a lower rating (3.0/5.0) and is relatively inexpensive ($8.33), but it seems like there are better options available for similar prices.\n* **Aveeno** has a very low rating (1.0/5.0) and may not be the best choice, considering its poor customer reviews.\n\nIf you have any specific hair concerns or preferences, I'd be happy to help you narrow down your options further!"
